# %% [markdown]
# # Exercise after class
#
# The goal of this exercise is to explore the NLTK library using the manual or online tutorials (avoid AI usage). First, create one (or more) texts in spanish (just copy paste it somewhere). The use the NLTK library of pure Python to performe at least this action to the text(s).
#
# 1. Case folding
# 2. Word normalization
# 3. Tokenization
# 4. Stemming
# 5. Lemmatization
# 6. Sentence segmentation
# 7. PoS Tagging
# 8. Named Entity Recognition (NER)
#
# Just try to explore and understand the library. Check in the reference book and NLTK manual for the new concepts.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk

# %%
import spacy

#Try loading the spanish model; if ot found, download it
try:
    nlp = spacy.load('es_core_news_sm')
except OSError:
    import spacy.cli
    spacy.cli.download('es_core_news_sm')
    nlp = spacy.load('es_core_news_sm')

text= "La inteligencia artificial está revolucionando el mundo. ¿Cómo afectará esto a nuestras vidas?"
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 542, in dispatch_queue
#     await self.process_one()
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 531, in process_one
#     await dispatch(*args)
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 775, in execute_request
#     reply_content = await reply_content
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/x9/s464tr3n2ng8_s8c_5cxv5800000gn/T/ipykernel_88274/3909930485.py", line 1, in <module>
#     import spacy
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/spacy/__init__.py", line 6, in <module>
#     from .errors import setup_default_warnings
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/spacy/errors.py", line 3, in <module>
#     from .compat import Literal
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/spacy/compat.py", line 4, in <module>
#     from thinc.util import copy_array
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/thinc/__init__.py", line 5, in <module>
#     from .config import registry
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/thinc/config.py", line 5, in <module>
#     from .types import Decorator
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/thinc/types.py", line 25, in <module>
#     from .compat import cupy, has_cupy
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/thinc/compat.py", line 35, in <module>
#     import torch
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/torch/__init__.py", line 1471, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/carlosillanaldariz/miniconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# Collecting es-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 23.3 MB/s eta 0:00:00 0:00:01
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
